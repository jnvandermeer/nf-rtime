# %%
pwd
# Out:
# '/home/johan/nf/nf-rtime/Projects_Templates/8_Replay_BWII'

# %%
from PyQt5 import QtCore, QtGui, QtWidgets

# %%
# %matplotlib qt5

# %% [markdown]
# ## note
# We can also use ```%gui qt```
#
# And especially, in the ipython_config.py file, there's an option to start the qt event loop (yes, that's a THING!) immediately upon the start of Qt
# This file is located somwwhere in .ipython/profile_default/
#
# .... google it
#
# Welcome to the slightly more complicated world of Python-Qt-Jupyter
#
# This is all integrated into matlab immedeately (although, try making GUI's in Matlab - they get STUCK and there is NO SOLVE)

# %%
a = QtWidgets.QApplication([])

# %%
main_timer = QtCore.QTimer(a)

# %%
def dummy_function():
    print('test\n')

# %%
dummy_function()
# Out:
# test

# %%
main_timer.timeout.connect(dummy_function)

# %%
main_timer.start(2000)
# Out:
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# test
#
# ...
