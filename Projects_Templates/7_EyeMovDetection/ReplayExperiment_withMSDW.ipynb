# %% [markdown]
# # Replaying Old Data
#
# - Work under a separate branch with git (i.e. git checkout -b my-new-branch)
#
# - Make a new folder in Projects (for your specific purposes)
#
# - Copy this ipynb file that folder
#
# - The data is stored on L-Drive
#
# - the main gist of re-playing existing data is:
#     - that your first load everything into a big matrix with mne
#     - then initialize a specific **amp** (i.e., the "replayamp")
#     - then do exactly the same as normal, with a while True loop with calls to amp.get_data()

# %%
# import all the needed stuff:

import time
import sys
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt

import easygui  # popup windows with buttons made easy
import mne  # EEGLAB for python
from IPython.display import clear_output  # to clear the cell output during while loop
import re  # regular expressions
import pickle  # to save/load data
import dynarray  # a growing numpy array

import logging
logging.basicConfig(level=logging.ERROR)

sys.path.append("../../mushu")  # driver for the amps
sys.path.append("../../mushu/libmushu")
import libmushu

sys.path.append("../../nftools")  # handy stuff needed for NF
from nftools.loopcontrol import LoopState
from nftools.analysis import convert_alld_allm_to_mne
from nftools.analysis import select_part_from_mne_dataset
from nftools.analysis import plot_compare_two_spectra


sys.path.append("../../wyrm")  # real-time data analysis
from wyrm.types import RingBuffer
from wyrm.types import BlockBuffer
from wyrm import io
from wyrm import processing as proc

import scipy
from scipy import signal

from collections import deque  # a FILO list useful for plotting!

### Thomas import ###
from msdw import MSDW
from peaks import eye_peaks
from blink_range import AR
import peakutils
import itertools
from numpy.linalg import multi_dot
from sklearn.decomposition import FastICA
### Thomas import end ###

# %%
# this is the replay notebook - so select a file for playback - this is for brainvision files.

#fn=easygui.fileopenbox(default='/media/ldrive/Lab_MichaelB/Johan/nf/rawdata/*.vhdr')
fn=easygui.fileopenbox(default='/media/ldrive/Lab_MichaelB/Johan/nf/rawdata/*.vhdr')
print(fn)

raw_fromfile = mne.io.read_raw_brainvision(fn)
montage=mne.channels.read_montage('standard_1005', ch_names=raw_fromfile.ch_names)  # always use MNE definitions
raw_fromfile.set_montage(montage)


### Thomas modified
raw_fromfile.load_data()
raw_fromfile.set_eeg_reference('average', projection=True)
raw_fromfile.apply_proj()

print('Raw_FromFile shape before: {0}'.format(raw_fromfile.get_data().shape))

raw_blinks = raw_fromfile.copy()
raw_blinks.load_data()
raw_blinks.crop(0,30)
raw_blinks.filter(1, None)

# %matplotlib qt5

ica = mne.preprocessing.ICA(method="infomax", random_state=1)
ica.fit(raw_blinks)
ica.plot_sources(inst=raw_blinks)
ica.plot_components(inst=raw_blinks)

blks = raw_blinks.get_data().T
pca_comps = ica.pca_components_
M = ica.mixing_matrix_
M_inv = np.linalg.inv(M)
S = np.identity(M.shape[0])
plt.figure(); plt.plot(blks[:,0]); plt.show()
print([M.shape, M_inv.shape, S.shape, blks.shape])
print('Raw shape: {0}'.format(raw_blinks.get_data().shape))
print('Raw_FromFile shape after: {0}'.format(raw_fromfile.get_data().shape))
### Thomas modified end ###
# Out:
# L:\Lab_MichaelB\Johan\nf\rawdata\CH005\eeg\CHall_S05_2018-10-17_15-55-38.vhdr
# Extracting parameters from L:\Lab_MichaelB\Johan\nf\rawdata\CH005\eeg\CHall_S05_2018-10-17_15-55-38.vhdr...
# Setting channel info structure...
# Currently, 1 trigger(s) will be dropped, such as [Impedance]. Consider using ``event_id`` to parse triggers that do not follow the 'S###' pattern.
# The following EEG sensors did not have a position specified in the selected montage: ['EOG']. Their position has been left untouched.
# Reading 0 ... 1169155  =      0.000 ...   584.577 secs...
# <ipython-input-2-4a7f8c45cb2b>:7: RuntimeWarning: Currently, 1 trigger(s) will be dropped, such as [Impedance]. Consider using ``event_id`` to parse triggers that do not follow the 'S###' pattern.
#   raw_fromfile = mne.io.read_raw_brainvision(fn)
# <ipython-input-2-4a7f8c45cb2b>:9: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: ['EOG']. Their position has been left untouched.
#   raw_fromfile.set_montage(montage)
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Raw_FromFile shape before: (65, 1169156)
# Setting up high-pass filter at 1 Hz
# l_trans_bandwidth chosen to be 1.0 Hz
# Filter length of 6601 samples (3.300 sec) selected
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# Inferring max_pca_components from picks
# Using all PCA components: 64
#
# Fitting ICA took 24.4s.
# [(64, 64), (64, 64), (64, 64), (60001, 65)]
# Raw shape: (65, 60001)
# Raw_FromFile shape after: (65, 1169156)

# %%
S[[3,7],:] = 0

# %%
# properties of the recording, and what we're doing here:
fs = raw_fromfile.info['sfreq']
nbchan = raw_fromfile.info['nchan']-1

updateTime = 0.1  # run some kind of calculation every X seconds
buffSize = 1.0  # run calculation on last X seconds of data

# %%
# %matplotlib qt5  
plt.ion()  # enable widget plots & interactive plots

time_in_plot=2.5
sy1=deque(np.zeros(round(fs * time_in_plot)), round(fs * time_in_plot))  # for plotting - the FILO list
sy2=deque(np.zeros(round(fs * time_in_plot)), round(fs * time_in_plot))  # for plotting - the FILO list
sy3=deque(np.zeros(round(fs * time_in_plot)), round(fs * time_in_plot))
sy4=deque(np.zeros(round(fs * time_in_plot)), round(fs * time_in_plot))
sy5=deque(np.zeros(round(fs * time_in_plot)), round(fs * time_in_plot))

channel_to_plot=0
sx = np.linspace(0, time_in_plot, round(fs * time_in_plot))

featuresy1 = deque(np.zeros(round(1/updateTime * time_in_plot)), round(1/updateTime * time_in_plot))
featuresx = np.linspace(0, time_in_plot, round(1/updateTime * time_in_plot))

# %%
# real-time data filtering -- high-pass filter (of 1.0 Hz)

f_low = 1.0
# f_high = 15.0
butter_ord = 3
lenchannels = 64

#rt_b, rt_a = signal.butter(butter_ord, [f_low / fn, f_high / fn], btype='band')
rt_b_hp, rt_a_hp = signal.butter(butter_ord, 2*f_low/fs, btype='high', analog=False)  # a digital high-pass filter
rt_zi_hp = proc.lfilter_zi(rt_b_hp, rt_a_hp, lenchannels)

# %%
# real-time data filtering -- band-pass filter (of 12.0 - 15.0 Hz)

f_low = 12.0
f_high = 15.0
butter_ord = 3
lenchannels = 64

#rt_b, rt_a = signal.butter(butter_ord, [f_low / fn, f_high / fn], btype='band')
rt_b_bp, rt_a_bp = signal.butter(butter_ord, [2*f_low/fs, 2*f_high/fs], btype='band', analog=False)  # a digital high-pass filter
rt_zi_bp = proc.lfilter_zi(rt_b_bp, rt_a_bp, lenchannels)

# %%
# prepare data for replay (warning: need probably a lot of memory)

mul_factor = 1.0
if 1e-6 in [raw_fromfile.info['chs'][0]['cal'], raw_fromfile.info['chs'][0]['range']]:
    mul_factor = 1.0 / 1e-6

seed_d=raw_fromfile[:-1,:][0] * mul_factor  # scale the data to seed (so no 1e-6 stuff in the replayed data)
seed_d=np.array(seed_d.transpose())
seed_ch=raw_fromfile.ch_names[0:-1]
seed_fs=raw_fromfile.info['sfreq']

# prepare for replay; markers:
seed_mdata=np.transpose(raw_fromfile[-1,:][0])
seed_m=[[i / raw_fromfile.info['sfreq'] * 1000, int(m[0])] for i, m in enumerate(seed_mdata) if m > 0]

# %%
amp = libmushu.get_amp('replayamp')
amp.configure(seed_d, seed_m, seed_ch, seed_fs, realtime=True, blocksize_samples=100)

# %%
alld=dynarray.DynamicArray((None, len(amp.get_channels())))     # data
allm=[]     # markers
sfreq = amp.get_sampling_frequency()  # sampling frequency
ch_names=amp.get_channels()  # channel names

markTime=time.time()


rb = RingBuffer(buffSize * 1000)  # the buffer containing the last X seconds of data - declared in MILISECONDS
totalTime = seed_d.shape[0]/raw_fromfile.info['sfreq']

# %%
amp.start()

# %%
fig=plt.figure(figsize=(20,12))  # plotting...
th=fig.suptitle('')
ah1=fig.add_subplot(221)
ah2=fig.add_subplot(222)
ah3=fig.add_subplot(223)
ah4=fig.add_subplot(224)
ah1.set_title("Raw EEG Signal")
ah2.set_title("Filtered EEG Signal")
ah3.set_title("ICA - Corrected EEG Signal")
ah4.set_title("MSDW Algorithm")

l1, = ah1.plot(sx, sy1)
l2, = ah2.plot(sx, sy2)
l3, = ah3.plot(sx, sy3)
l4, = ah4.plot(sx, sy4)
#l5, = ah1.axvspan(1.5, 1.8, alpha=0.2, color='#F08080', lw=0)

featurefig = plt.figure()
featureth=featurefig.suptitle('')
featureah=featurefig.add_subplot(111)
featurel1, = featureah.plot(featuresx, featuresy1)

# l=LoopState(); l.start()
markeroffset = 0  # needed to store all data in one big mat/vector
t0=time.time()
curTime=time.time()
st=''
eyeblinks = 0
while curTime - t0 < totalTime:  # l.get_state() != 'Stop':
   
    
    # keep track of time:
    curTime = time.time()
    
    # this is where you get the data
    data, marker = amp.get_data()
    
    if data.shape[0] > 0:  # this is crucial for remembering filter state.
        
        cnt = io.convert_mushu_data(data, marker, sfreq, ch_names)

        f_cnt, rt_zi_bp = proc.lfilter(cnt, rt_b_bp, rt_a_bp, zi=rt_zi_bp)  # real-time data preprocessing...        
        
        out1, out2, out3 = MSDW(cnt.data[:,channel_to_plot], 70, 500)
        AR(cnt.data[:,channel_to_plot], 70, 500, 80, 0.4, out1, MSDW.windowSize4msdw)
        
        len_out1 = len(out1[out3:])
        ext = np.zeros((len_out1,))
        
        if AR.range_.shape[0] > 0:
            print(AR.range_)
            #for i in range(AR.range_.shape[0]):
                #ah1.axvspan(AR.range_[i][0],AR.range_[i][1], alpha=0.2, color='#F08080', lw=0)
        
        eyeblinks += AR.range_.shape[0]

        # plotting...
        
        eb_data = cnt.data[:,channel_to_plot]
        
        data_corrected = multi_dot([pca_comps.T, M, S, M_inv, pca_comps, cnt.data.T])
        
        #shades = np.arange(0, cnt.data.shape[0])
        #shades[100] = 1
        #shades[150] = 2
        
        sy1.extend(eb_data[out3:])  # to visualize/plot -- sy1 and sy2 are deque's
        sy2.extend(f_cnt.data[out3:,channel_to_plot])
        sy3.extend(data_corrected[channel_to_plot,out3:])
        sy4.extend(out1[out3:])
        
        print('eb_data shape: {0}'.format(eb_data.shape))
        print('data_corrected shape: {0}'.format(data_corrected.shape))
        
        
        if out1[out3] in sy3:
            first_elem = np.where(sy3==out1[out3])[0][0]
            print(first_elem)
        
        lines = np.zeros((4000,)) 
        lines[2000] = 1 
        data_lines = [sy1, lines]
    
        
        l1.set_ydata(sy1)  
        l2.set_ydata(sy2)
        l3.set_ydata(sy3)
        l4.set_ydata(sy4)
        
        
        msy1=np.mean(sy1)
        msy2=np.mean(sy2)
        msy3=np.mean(sy3)
        msy4=np.mean(sy4)
        ah1.set_ylim(-150+msy1, 200+msy1)
        ah2.set_ylim(-10+msy2, 10+msy2)
        ah3.set_ylim(-150+msy3, 200+msy3)
        ah4.set_ylim(-250+msy4, 250+msy4)

        fig.canvas.draw()
        fig.canvas.flush_events()
        
        # currently has no purpose
        newsamples = cnt.data.shape[0]

        # append to ringbuffer, so we can calculate features later on on the last N secs/samples of data.
        rb.append(f_cnt)

        # append it to the big matrix, for saving later on with pickle.
        alld.extend(data)
        for m in marker:
            allm.append([m[0] + markeroffset, m[1]])
        markeroffset += newsamples / float(sfreq) * 1000.
        


        # do the following every 0.1 msec - with with the ringbuffer:
        if curTime - markTime > updateTime:
            # do Stuff

            markTime = curTime
            # 1) obtain last 1-second(s)
            d = rb.get()

            # thomas does stuff here - in this example, we take channel 1 of the data and filter it
            feature = np.log10(np.mean(abs(d.data[:,0]))) * 10
            featuresy1.append(feature)
            
            # we send the value to BCI/STIM here - but not right now
            # bcinet.send_signal(bcixml.BciSignal({'nfsignal': signalToSend},None, bcixml.CONTROL_SIGNAL))
            featureMax = 0
            featureMin = -6.0
            featureScaling = 1/abs(featureMax - featureMin)
            featureOffset = (featureMax + featureMin) / 2
            signalToSend = featureScaling * (feature - featureOffset)

            # plot of the feature in a separate figure, to keep track:
            featurel1.set_ydata(featuresy1) # plotting the feature stuff
            featuremsy1=np.mean(featuresy1)
            featureah.set_ylim(-10+featuremsy1, 10+featuremsy1)
            
            featurefig.canvas.draw()
            featurefig.canvas.flush_events()

            # clear_output(wait=True)  # write some logging information here
            # clear_output clear the output of the cell, but if you do that you also remove the figures, it seems
            # so don't do it!
            str1 = 'Playing Back - time = %f' % (curTime - t0)
            str2 = 'Length Markers: %d' % len(allm)
            str3 = '%d, %d' % data.shape
            str4 = 'Feature Value: %f' % feature
            str5 = 'Scaled Signal for NF: %f' % signalToSend
            str6 = 'Eyeblinks: %d' % eyeblinks
            #print(str1 + '\n' + str2 + '\n' + str3 + '\n' + str4 + '\n' + str5)
            
            # print('Length Markers: %d' % len(allm))
            # print(data.shape)
            th.set_text(str1 + '\n' + str2 + '\n' +str3 + '\n' + str6 + '\n')
            featureth.set_text(str4 + '\n' + str5)
# Out:
# [[  572.  1567.]
#  [ 1567.  2160.]
#  [ 2336.  2648.]]
# eb_data shape: (2700,)
# data_corrected shape: (64, 2700)
# [[   83.   851.]
#  [  851.  1689.]]
# eb_data shape: (2400,)
# data_corrected shape: (64, 2400)
# [[   11.  1010.]]
# eb_data shape: (1700,)
# data_corrected shape: (64, 1700)
# eb_data shape: (1400,)
# data_corrected shape: (64, 1400)
# eb_data shape: (1100,)
# data_corrected shape: (64, 1100)
# eb_data shape: (900,)
# data_corrected shape: (64, 900)
# eb_data shape: (700,)
# data_corrected shape: (64, 700)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[   2.  298.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[ 157.  396.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# [[   2.  189.]]
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (1000,)
# data_corrected shape: (64, 1000)
# eb_data shape: (900,)
# data_corrected shape: (64, 900)
# eb_data shape: (800,)
# data_corrected shape: (64, 800)
# eb_data shape: (700,)
# data_corrected shape: (64, 700)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[ 203.  398.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# ...
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# [[  44.  294.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  36.  355.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (600,)
# data_corrected shape: (64, 600)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (500,)
# data_corrected shape: (64, 500)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[  29.  263.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  96.  343.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[  22.  170.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (200,)
# data_corrected shape: (64, 200)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  93.  270.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  62.  372.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[  68.  241.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[ 143.  283.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  23.  107.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  61.  170.]
#  [ 172.  287.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  25.  247.]
#  [ 247.  274.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  43.  241.]
#  [ 308.  388.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[ 177.  259.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  31.  116.]
#  [ 116.  285.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  49.  128.]
#  [ 185.  288.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[ 110.  292.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[   7.  111.]
#  [ 116.  256.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[  83.  178.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  52.  196.]
#  [ 196.  226.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# [[  73.  256.]]
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# [[  81.  361.]]
# eb_data shape: (400,)
# data_corrected shape: (64, 400)
# eb_data shape: (300,)
# data_corrected shape: (64, 300)
# eb_data shape: (256,)
# data_corrected shape: (64, 256)

# %%
len(featuresy1)

# %%
amp.stop()
alld.shrink_to_fit()
# Out:
# amplifier stopped!

# %%
# write to disk, so we can re-load it later:

t={'alld':alld, 'allm':allm, 'ch_names':ch_names, 'sfreq':sfreq}
with open('c-allm-and-alld.pkl', 'wb') as f:
    pickle.dump(t, f)

# %%
# load from disk:

with open('c-allm-and-alld.pkl','rb') as f:
    t=pickle.load(f)
for key in t.keys():
    locals()[key] = t[key]

# %%
raw = convert_alld_allm_to_mne(alld, allm, ch_names, sfreq)  # covert to MNE
raw.resample(1000)
# Out:
# The following EEG sensors did not have a position specified in the selected montage: ['EOG']. Their position has been left untouched.
# ../../nftools\nftools\analysis.py:31: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: ['EOG']. Their position has been left untouched.
#   montage=montage
# Creating RawArray with float64 data, n_channels=64, n_times=1169156
#     Range : 0 ... 1169155 =      0.000 ...   584.577 secs
# Ready.
# 2000.0
# Creating RawArray with float64 data, n_channels=1, n_times=1169156
#     Range : 0 ... 1169155 =      0.000 ...   584.577 secs
# Ready.
# 1 events found
# Event IDs: [1001]
# 1 events found
# Event IDs: [1001]
# <RawArray  |  None, n_channels x n_times : 65 x 584578 (584.6 sec), ~290.1 MB, data loaded>

# %%
raw.plot(scalings='auto');

# %%
# raw.set_eeg_reference(ref_channels='average')
# better not (yet) - before removing bad channels, since these mess up your data big time: see PREP paper:
# %matplotlib qt5

# %%
picks = mne.pick_types(raw.info, meg=False, eeg=True, eog=False,
                       stim=False, exclude='bads')

raw.notch_filter(np.arange(50, 300, 50), picks=picks, filter_length='auto', phase='zero')
# add it (potentialy) some other preprocessing steps here
# Out:
# Setting up band-stop filter
# Filter length of 6601 samples (6.601 sec) selected
# <RawArray  |  None, n_channels x n_times : 65 x 584578 (584.6 sec), ~290.1 MB, data loaded>

# %%
# split data sets between EO and EC

newraw_eo=select_part_from_mne_dataset(raw, markers=[201, 202])
newraw_ec=select_part_from_mne_dataset(raw, markers=[203, 204])
# Out:
# using markers
# 1 events found
# Event IDs: [1001]
# using boundaries
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-a83fb0fd22d8> in <module>()
#       1 # split data sets between EO and EC
#       2
# ----> 3 newraw_eo=select_part_from_mne_dataset(raw, markers=[201, 202])
#       4 newraw_ec=select_part_from_mne_dataset(raw, markers=[203, 204])
#
# ~\nf\nf-rtime\nftools\nftools\analysis.py in select_part_from_mne_dataset(rawin, **kwargs)
#     141             raise Exception('cannot find nice segments')
#     142
# --> 143         newraw = select_part_from_mne_dataset(rawin, boundaries=list(zip(allbs, alles)))
#     144
#     145         return(newraw)
#
# ~\nf\nf-rtime\nftools\nftools\analysis.py in select_part_from_mne_dataset(rawin, **kwargs)
#     104
#     105         newdat=[]
# --> 106         if isinstance(boundaries[0], list) or isinstance(boundaries[0], tuple):
#     107             for item in boundaries:
#     108                 b, e = item
#
# IndexError: list index out of range

# %%
d1=plot_compare_two_spectra(newraw_eo, newraw_ec, freqs=[1, 25], n_fft=2048, n_overlap=512, chs_to_include=['Oz','O1'], freq_lims_topoplot=[7, 12], pow_lims = [-10, 25]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9075291662c0> in <module>()
# ----> 1 d1=plot_compare_two_spectra(newraw_eo, newraw_ec, freqs=[1, 25], n_fft=2048, n_overlap=512, chs_to_include=['Oz','O1'], freq_lims_topoplot=[7, 12], pow_lims = [-10, 25]);
#
# NameError: name 'newraw_eo' is not defined

# %%
plt.figure();plt.plot(newraw_eo[0,0:1000][0].transpose());
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e1e7dea48da8> in <module>()
# ----> 1 plt.figure();plt.plot(newraw_eo[0,0:1000][0].transpose());
#
# NameError: name 'newraw_eo' is not defined

# %%
newraw_eo.plot(scalings='auto');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1083063e3741> in <module>()
# ----> 1 newraw_eo.plot(scalings='auto');
#
# NameError: name 'newraw_eo' is not defined

# %%
mne.viz.plot_sensors(newraw_ec.info, show_names=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a1a7599f207c> in <module>()
# ----> 1 mne.viz.plot_sensors(newraw_ec.info, show_names=True);
#
# NameError: name 'newraw_ec' is not defined

# %%
newraw_eo.plot_psd(tmax=np.inf, fmax=250, n_fft=2048);
newraw_ec.plot_psd(tmax=np.inf, fmax=250, n_fft=2048);
# Out:
# Effective window size : 2.048 (s)
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\mne\viz\evoked.py:162: RuntimeWarning: invalid value encountered in maximum
#   rgb /= np.maximum(rgb.max(0), 1e-16)  # avoid div by zero
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\matplotlib\colors.py:233: RuntimeWarning: invalid value encountered in less
#   if np.any((result < 0) | (result > 1)):
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\matplotlib\colors.py:233: RuntimeWarning: invalid value encountered in greater
#   if np.any((result < 0) | (result > 1)):
# Effective window size : 2.048 (s)
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\mne\viz\evoked.py:162: RuntimeWarning: invalid value encountered in maximum
#   rgb /= np.maximum(rgb.max(0), 1e-16)  # avoid div by zero
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\matplotlib\colors.py:233: RuntimeWarning: invalid value encountered in less
#   if np.any((result < 0) | (result > 1)):
# C:\Users\thomasD\AppData\Local\Continuum\anaconda3\envs\rt\lib\site-packages\matplotlib\colors.py:233: RuntimeWarning: invalid value encountered in greater
#   if np.any((result < 0) | (result > 1)):

# %%
## some attempts at doing ICA
#from mne.preprocessing import ICA
#method = 'fastica'
#n_components = 25
#decim = 3
#random_state = 23
#ica = ICA(n_components=n_components, method=method, random_state=random_state)
#print(ica)
#
#picks_eeg = mne.pick_types(newraw_ec.info, meg=False, eeg=True, eog=False,
#                           stim=False, exclude='bads')
#reject = dict(eeg=1e-3)
#ica.fit(newraw_ec, picks=picks_eeg, decim=decim, reject=reject)
#print(ica)

# %%
# close all of the figures.
# %matplotlib qt5
