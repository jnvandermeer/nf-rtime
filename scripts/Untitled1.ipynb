# %%
breakpoint()
# Out:
# pudb:6899: Please telnet into 127.0.0.1 6899.
# pudb:6899: Waiting for client...
#
# pudb:6899: Now in session with 127.0.0.1:35212.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.conda/envs/rt/lib/python3.7/site-packages/pudb/debugger.py in call_with_ui(self, f, *args, **kwargs)
#    2146         try:
# -> 2147             return f(*args, **kwargs)
#    2148         finally:
#
# ~/.conda/envs/rt/lib/python3.7/site-packages/pudb/debugger.py in interaction(self, exc_tuple, show_exc_dialog)
#    2398         self.caption.set_text(caption)
# -> 2399         self.event_loop()
#    2400
#
# ~/.conda/envs/rt/lib/python3.7/site-packages/pudb/debugger.py in event_loop(self, toplevel)
#    2358                 self.screen.draw_screen(self.size, canvas)
# -> 2359                 keys = self.screen.get_input()
#    2360
#
# ...
